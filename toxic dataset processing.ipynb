# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
toxic_original = pd.read_csv("/content/gdrive/MyDrive/Dataset/train.csv").fillna(' ')

# %%
toxic_original.head()
# Out:
#       id    target                                       comment_text  \
# 0  59848  0.000000  This is so cool. It's like, 'would you want yo...
# 1  59849  0.000000  Thank you!! This would make my life a lot less...
# 2  59852  0.000000  This is such an urgent design problem; kudos t...
# 3  59855  0.000000  Is this something I'll be able to install on m...
# 4  59856  0.893617               haha you guys are a bunch of losers.
#
#    severe_toxicity  obscene  identity_attack   insult  threat asian atheist  \
# 0         0.000000      0.0         0.000000  0.00000     0.0
# 1         0.000000      0.0         0.000000  0.00000     0.0
# 2         0.000000      0.0         0.000000  0.00000     0.0
# 3         0.000000      0.0         0.000000  0.00000     0.0
# 4         0.021277      0.0         0.021277  0.87234     0.0   0.0     0.0
#
#    ... article_id    rating funny wow sad likes disagree sexual_explicit  \
# ...

# %%
toxic_result = []
for i in toxic_original['target']:
  if i >= 0.5: 
    toxic_result.append(1) # 1 means toxic
  else:
    toxic_result.append(0) # 0 means non-toxic
toxic_original['toxic_result'] = toxic_result

# %%
toxic_original.head(20)
# Out:
#         id    target                                       comment_text  \
# 0    59848  0.000000  This is so cool. It's like, 'would you want yo...
# 1    59849  0.000000  Thank you!! This would make my life a lot less...
# 2    59852  0.000000  This is such an urgent design problem; kudos t...
# 3    59855  0.000000  Is this something I'll be able to install on m...
# 4    59856  0.893617               haha you guys are a bunch of losers.
# 5    59859  0.666667                               ur a sh*tty comment.
# 6    59861  0.457627                        hahahahahahahahhha suck it.
# 7    59863  0.000000                                FFFFUUUUUUUUUUUUUUU
# 8   239575  0.000000  The ranchers seem motivated by mostly by greed...
# 9   239576  0.000000  It was a great show. Not a combo I'd of expect...
# 10  239578  0.000000                            Wow, that sounds great.
# 11  239579  0.440000  This is a great story. Man. I wonder if the pe...
# ...

# %%
toxic_original.shape
# Out:
# (1804874, 46)

# %%
toxic_1 = toxic_original['target'] >= 0.5
toxic_df_1 = pd.DataFrame(toxic_original[toxic_1])
toxic_df_1 # check number of toxic text
# Out:
#               id    target                                       comment_text  \
# 4          59856  0.893617               haha you guys are a bunch of losers.
# 5          59859  0.666667                               ur a sh*tty comment.
# 13        239583  0.600000  It's ridiculous that these guys are being call...
# 14        239584  0.500000  This story gets more ridiculous by the hour! A...
# 19        239592  0.500000  Angry trolls, misogynists and Racists", oh my....
# ...          ...       ...                                                ...
# 1804825  6333841  0.833333  Who is the jerk in the last row between the C ...
# 1804838  6333871  0.700000  Nobody really cares that she supports the scie...
# 1804856  6333923  0.500000  Believing in God or not believing in God are p...
# 1804857  6333927  0.700000  I take your point, but I think you're shooting...
# 1804872  6334009  0.621212  Anyone who is quoted as having the following e...
#
# ...

# %%
#toxic_df_1 = toxic_df_1.iloc[:15000]
#random select 15000 rows with target(toxic) value >= 0.5
toxic_df_1 = toxic_df_1.sample(n=15000)
toxic_df_1 # select the non toxic text, make it as
# Out:
#               id    target                                       comment_text  \
# 1751343  6268913  0.637931  Ridiculous.  Now our homes will be as "insulat...
# 1208289  5592396  0.777778  ... and this man, a partisan hack and despicab...
# 827809   5133949  0.712500  China look at your own record which explains y...
# 441028    783839  0.672727                                      Fire them all
# 125289    395194  0.500000  And progressive racists will always try and sh...
# ...          ...       ...                                                ...
# 168250    447773  0.500000  No one died, everyone was able to get out of t...
# 91633     354601  0.700000  Catering to the need to kill until there is no...
# 28003     276165  0.539474  Do you believe black people are more violent t...
# 228083    521873  0.500000  May I recommend watching PBS Frontline: The Ch...
# 1046825  5396650  0.500000  "Christian Fundamentalists" , also known as th...
#
# ...

# %%
toxic_0 = toxic_original['target'] < 0.5
toxic_df_0 = pd.DataFrame(toxic_original[toxic_0])
toxic_df_0 # check number of toxic text
# Out:
#               id    target                                       comment_text  \
# 0          59848  0.000000  This is so cool. It's like, 'would you want yo...
# 1          59849  0.000000  Thank you!! This would make my life a lot less...
# 2          59852  0.000000  This is such an urgent design problem; kudos t...
# 3          59855  0.000000  Is this something I'll be able to install on m...
# 6          59861  0.457627                        hahahahahahahahhha suck it.
# ...          ...       ...                                                ...
# 1804868  6333965  0.000000  cont....GBA:  "here's the summation of that "l...
# 1804869  6333967  0.000000  Maybe the tax on "things" would be collected w...
# 1804870  6333969  0.000000  What do you call people who STILL think the di...
# 1804871  6333982  0.000000  thank you ,,,right or wrong,,, i am following ...
# 1804873  6334010  0.000000  Students defined as EBD are legally just as di...
#
# ...

# %%
#toxic_df_0 = toxic_df_0.iloc[:15000]
toxic_df_0 = toxic_df_0.sample(n=15000) #random select 15000 rows with target(toxic) value less than 0.5
toxic_df_0 # select the non toxic text, make it as
# Out:
#               id    target                                       comment_text  \
# 1790237  6315551  0.000000  That is your view of the situation.   I have m...
# 36043     285872  0.000000  Nero fiddled while Rome burned.  Dunleavy's ph...
# 612401    991635  0.000000                               That's a good point.
# 1194349  5575510  0.200000  Well I have been a longtime and vociferous cri...
# 616737    996987  0.166667  Dishonest?  No, not I.....\n\nYou purposefully...
# ...          ...       ...                                                ...
# 782424   5078136  0.000000  I'd say that's 100% certain that they provide ...
# 1609361  6091885  0.166667  President Trump routinely denounces as fake ne...
# 1148402  5520651  0.000000  Millsap is probably the highest paid player in...
# 466105    815722  0.400000  And Trump is part of what set? Certainly not "...
# 625767   1007781  0.166667  The problem is that that news conference was m...
#
# ...

# %%
toxic_df_0_copy = toxic_df_0

# %%
toxic_df_0_copy
# Out:
#               id    target                                       comment_text  \
# 1790237  6315551  0.000000  That is your view of the situation.   I have m...
# 36043     285872  0.000000  Nero fiddled while Rome burned.  Dunleavy's ph...
# 612401    991635  0.000000                               That's a good point.
# 1194349  5575510  0.200000  Well I have been a longtime and vociferous cri...
# 616737    996987  0.166667  Dishonest?  No, not I.....\n\nYou purposefully...
# ...          ...       ...                                                ...
# 782424   5078136  0.000000  I'd say that's 100% certain that they provide ...
# 1609361  6091885  0.166667  President Trump routinely denounces as fake ne...
# 1148402  5520651  0.000000  Millsap is probably the highest paid player in...
# 466105    815722  0.400000  And Trump is part of what set? Certainly not "...
# 625767   1007781  0.166667  The problem is that that news conference was m...
#
# ...

# %%
toxic_original_selected = toxic_df_0_copy.append(toxic_df_1, ignore_index=True)

# %%
toxic_original_selected
# Out:
#             id    target                                       comment_text  \
# 0      6315551  0.000000  That is your view of the situation.   I have m...
# 1       285872  0.000000  Nero fiddled while Rome burned.  Dunleavy's ph...
# 2       991635  0.000000                               That's a good point.
# 3      5575510  0.200000  Well I have been a longtime and vociferous cri...
# 4       996987  0.166667  Dishonest?  No, not I.....\n\nYou purposefully...
# ...        ...       ...                                                ...
# 29995   447773  0.500000  No one died, everyone was able to get out of t...
# 29996   354601  0.700000  Catering to the need to kill until there is no...
# 29997   276165  0.539474  Do you believe black people are more violent t...
# 29998   521873  0.500000  May I recommend watching PBS Frontline: The Ch...
# 29999  5396650  0.500000  "Christian Fundamentalists" , also known as th...
#
# ...

# %%
toxic_original_selected.to_csv("/content/gdrive/MyDrive/toxic_original_selected.csv", sep=',',index=False)
